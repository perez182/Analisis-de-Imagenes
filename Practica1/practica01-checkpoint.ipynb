# %% [markdown]
# # Image Analysis
# **Alumno Perez Bautista David **
#
# 00 - PRACTICA 1

# %% [markdown]
# **Import <a href="https://numpy.org">NumPy</a>, <a href="https://matplotlib.org">matplotlib</a> and Image from <a href="https://pillow.readthedocs.io/en/stable/">PIL</a>**

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image

# %% [markdown]
# **Using PIL and matplotlib to read and display images.**

# %%
filepath="./" #The current directory
#filename="mark.jpeg" #The File name
filename="coins.png"
pic=Image.open(filepath+filename) #Open the image
pic #Diplays the image in the notebook
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=297x244 at 0x211546AE198>

# %% [markdown]
# **Converting the image as an array**

# %%
pic_arr = np.asarray(pic) #converts the image to an Numpy Array
pic_arr.shape #(height,width,#of channels)
# Out:
# (244, 297, 4)

# %%
pic_arr
# Out:
# array([[[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[ 27,  27,  27, 255],
#         [ 29,  29,  29, 255],
#         [ 27,  27,  27, 255],
#         ...,
#         [ 37,  37,  37, 255],
#         [ 38,  38,  38, 255],
#         [ 35,  35,  35, 255]],
#
#        [[ 29,  29,  29, 255],
#         [ 27,  27,  27, 255],
#         [ 30,  30,  30, 255],
#         ...,
#         [ 36,  36,  36, 255],
#         [ 36,  36,  36, 255],
#         [ 37,  37,  37, 255]],
#
#        ...,
#
#        [[ 53,  53,  53, 255],
#         [ 52,  52,  52, 255],
#         [ 54,  54,  54, 255],
#         ...,
#         [ 54,  54,  54, 255],
#         [ 52,  52,  52, 255],
#         [ 51,  51,  51, 255]],
#
#        [[ 54,  54,  54, 255],
#         [ 53,  53,  53, 255],
#         [ 51,  51,  51, 255],
#         ...,
#         [ 55,  55,  55, 255],
#         [ 52,  52,  52, 255],
#         [ 49,  49,  49, 255]],
#
#        [[ 52,  52,  52, 255],
#         [ 52,  52,  52, 255],
#         [ 51,  51,  51, 255],
#         ...,
#         [ 54,  54,  54, 255],
#         [ 53,  53,  53, 255],
#         [ 49,  49,  49, 255]]], dtype=uint8)

# %%
plt.imshow(pic_arr) #using pyplot (plt) to display the array as an image

# %% [markdown]
# **Using slicing to set the GREEN and BLUE channels of the picture to 0, then using imshow() to show the isolated RED channel**

# %%
pic_red=pic_arr.copy()
#pic_red=pic_red[:,:,0] #0=red
#plt.imshow(pic_red,cmap='gray') #as grayscale
pic_red[:,:,1]=0
pic_red[:,:,2]=0
plt.imshow(pic_red)

# %% [markdown]
# **Using slicing to set the RED and BLUE channels of the picture to 0, then using imshow() to show the isolated GREEN channel**

# %%
pic_green=pic_arr.copy()
#pic_green=pic_green[:,:,1] #1=green
#plt.imshow(pic_green,cmap='gray') #as grayscale
pic_green[:,:,0]=0
pic_green[:,:,2]=0
plt.imshow(pic_green)

# %% [markdown]
# **Using slicing to set the RED and GREEN channels of the picture to 0, then using imshow() to show the isolated BLUE channel**

# %%
pic_blue=pic_arr.copy()
#pic_blue=pic_blue[:,:,2] #2=blue
#plt.imshow(pic_blue,cmap='gray') #as grayscale
pic_blue[:,:,0]=0
pic_blue[:,:,1]=0
plt.imshow(pic_blue)

# %% [markdown]
# **Calculating the histograms for the three channels and displays them**

# %%
#Get the height and the width
height=pic_arr.shape[0]
width=pic_arr.shape[1]

#RED CHANNEL
hist_red=np.zeros(256)
for i in range(0,height):   #FOR EVERY ROW   
    for j in range(0,width):   #FOR EVERY COLUMN
        hist_red[pic_red[i,j,0]]+=1
#plt.plot(hist_red,color = "r")

#GREEN CHANNEL
hist_green=np.zeros(256)
for i in range(0,height):   #FOR EVERY ROW   
    for j in range(0,width):   #FOR EVERY COLUMN
        hist_green[pic_green[i,j,1]]+=1
#plt.plot(hist_green,color = "g")

#BLUE CHANNEL
hist_blue=np.zeros(256)
for i in range(0,height):   #FOR EVERY ROW   
    for j in range(0,width):   #FOR EVERY COLUMN
        hist_blue[pic_blue[i,j,2]]+=1
#plt.plot(hist_blue,color = "b")

fig, axs = plt.subplots(1, 3, figsize=(20,5), sharey=True)
axs[0].plot(hist_red,color = "r")
axs[0].set_xlabel("red")
axs[1].plot(hist_green,color = "g")
axs[1].set_xlabel("green")
axs[2].plot(hist_blue,color = "b")
axs[2].set_xlabel("blue")
fig.suptitle('Histogram channels')
# Out:
# Text(0.5, 0.98, 'Histogram channels')

# %% [markdown]
# **using otsu's algorithm to find the threshold, just with the read histogram**

# %%
w0=np.zeros(256)
P=np.zeros(256)
thresholds=np.zeros(256)
u0=np.zeros(256)
u1=np.zeros(256)
N=0 #Probability Pi=his_red[i]/N
for i in range(0,256):
    N+=hist_red[i]
    
for i in range(0,256):
    P[i]=hist_red[i]/N

#Get w0
w0[0]=P[0]
for i in range(1,256):
    w0[i]=w0[i-1]+P[i]
    
#Get u0
for i in range(1,256):
    u0[i]=(i*P[i])/w0[i]
    
#get u1
for i in range(0,256):
    aux=0;
    for j in range(i,256):
        aux+=j*P[j]
    u1[i]=aux/(1-w0[i])

#get thresholds

for i in range(0,256):
    thresholds[i]=w0[i]*(1-w0[i])*(pow((u0[i]-u1[i]),2))
 
thresholds
# Out:
# array([ 1.10407579e-01,  3.26313048e-01,  1.17547351e+00,  1.73004207e+00,
#         2.37076082e+00,  3.70721757e+00,  3.86593363e+00,  5.45501675e+00,
#         7.11024087e+00,  8.73236184e+00,  1.02686505e+01,  1.18675617e+01,
#         1.36544254e+01,  1.54951600e+01,  1.75671259e+01,  1.94362756e+01,
#         2.11703158e+01,  2.17958107e+01,  2.32698203e+01,  2.53955044e+01,
#         2.74728049e+01,  2.97629575e+01,  3.22081855e+01,  3.44276725e+01,
#         3.68596100e+01,  4.01489845e+01,  4.39401586e+01,  5.04650146e+01,
#         5.63182936e+01,  6.63669302e+01,  1.00129317e+02,  1.56005400e+02,
#         2.28744428e+02,  3.08827119e+02,  3.94305739e+02,  4.82223607e+02,
#         5.79253784e+02,  7.04422429e+02,  8.65880499e+02,  9.82618463e+02,
#         1.05282383e+03,  1.25599657e+03,  1.46189464e+03,  1.66309675e+03,
#         1.85231233e+03,  2.03095389e+03,  2.21628298e+03,  2.40929344e+03,
#         2.61116548e+03,  2.81610834e+03,  2.89402403e+03,  3.03175416e+03,
#         3.31988640e+03,  3.77654463e+03,  4.41006738e+03,  5.13401456e+03,
#         5.79864652e+03,  6.34272269e+03,  6.57706863e+03,  6.61158506e+03,
#         6.60488647e+03,  6.59331098e+03,  6.60658358e+03,  6.61076036e+03,
#         6.61609175e+03,  6.62328504e+03,  6.62734693e+03,  6.63580649e+03,
#         6.63988682e+03,  6.64494749e+03,  6.64842576e+03,  6.65479102e+03,
#         6.65151202e+03,  6.65983933e+03,  6.66190697e+03,  6.67011276e+03,
#         6.67119211e+03,  6.67309194e+03,  6.67835883e+03,  6.68231258e+03,
#         6.68532386e+03,  6.69096731e+03,  6.69577313e+03,  6.69175508e+03,
#         6.70345455e+03,  6.70833366e+03,  6.71194787e+03,  6.71687454e+03,
#         6.72113459e+03,  6.72966768e+03,  6.73136754e+03,  6.73955392e+03,
